# %%
# import dependencies
import pandas as pd
from sqlalchemy import create_engine, text

# Add the parent directory to sys.path to import config
import sys
import os
sys.path.append(os.path.abspath(os.path.join("../../..")))
import config

# %%
# connect to database
db_url = f"postgresql://postgres:{config.password}@localhost:5432/{config.database}"
engine = create_engine(db_url)

# %%
# function to read data from database
def read_db_to_df(query):
    with engine.connect() as conn:
        return pd.read_sql(query, conn)
    
# get df
df = read_db_to_df("SELECT * FROM map_listings")

# Print the number of rows in the DataFrame
print(f"Number of listings: {df.shape[0]}")

df.head()
# Out:
# Number of listings: 4928
#    latitude  longitude                   hover_description  \
# 0  38.86339  -76.98889                     Vita's Hideaway
# 1  38.91195  -77.00456    Historic Rowhouse Near Monuments
# 2  38.88719  -76.99472  Capitol Hill Bedroom walk to Metro
# 3  38.90585  -76.94469           Bertina's  House Part One
# 4  38.91887  -77.04008            Cozy apt in Adams Morgan
#
#                          listing_url  price              property_type  \
# 0  https://www.airbnb.com/rooms/3686   67.0       Private room in home
# 1  https://www.airbnb.com/rooms/3943   82.0  Private room in townhouse
# 2  https://www.airbnb.com/rooms/4197  135.0       Private room in home
# 3  https://www.airbnb.com/rooms/4529   66.0       Private room in home
# 4  https://www.airbnb.com/rooms/5589  129.5         Entire rental unit
#
#          room_type  accommodates  review_scores_rating host_name  \
# 0     Private room             1                  4.64      Vita
# 1     Private room             2                  4.85      Vasa
# 2     Private room             1                  4.86    Sandra
# 3     Private room             2                  4.66   Bertina
# 4  Entire home/apt             3                  4.50       Ami
#
#    host_identity_verified  host_total_listings_count  \
# 0                    True                          4
# 1                    True                          5
# 2                    True                          2
# 3                    True                          4
# 4                    True                          4
#
#                             license  \
# 0                              None
# 1  Hosted License: 5007242201001033
# 2  Hosted License: 5007242201000749
# 3                            Exempt
# 4                              None
#
#                                        neighbourhood
# 0                                 Historic Anacostia
# 1  Edgewood, Bloomingdale, Truxton Circle, Eckington
# 2                         Capitol Hill, Lincoln Park
# 3                       Eastland Gardens, Kenilworth
# 4     Kalorama Heights, Adams Morgan, Lanier Heights

# %%
# Get the current working directory
notebook_dir = os.getcwd()

# Define the CSV file path in the same directory as the notebook
csv_file_path = os.path.join(notebook_dir, 'airbnb_data.csv')

# export data to csv
df.to_csv(csv_file_path, index=False)
